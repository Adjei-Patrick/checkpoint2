# %%
# écire un programme pour savoir les nombres divisiblent par 7 entre 2000 et 3200
for i in range(2000,3201):
    if i % 7 == 0 and i % 5 != 0 :
        print(i, "est divible par 7 " + "mais n'est pas multiple de 5")
# Out:
# 2002 est divible par 7 mais n'est pas multiple de 5
# 2009 est divible par 7 mais n'est pas multiple de 5
# 2016 est divible par 7 mais n'est pas multiple de 5
# 2023 est divible par 7 mais n'est pas multiple de 5
# 2037 est divible par 7 mais n'est pas multiple de 5
# 2044 est divible par 7 mais n'est pas multiple de 5
# 2051 est divible par 7 mais n'est pas multiple de 5
# 2058 est divible par 7 mais n'est pas multiple de 5
# 2072 est divible par 7 mais n'est pas multiple de 5
# 2079 est divible par 7 mais n'est pas multiple de 5
# 2086 est divible par 7 mais n'est pas multiple de 5
# 2093 est divible par 7 mais n'est pas multiple de 5
# 2107 est divible par 7 mais n'est pas multiple de 5
# 2114 est divible par 7 mais n'est pas multiple de 5
# 2121 est divible par 7 mais n'est pas multiple de 5
# 2128 est divible par 7 mais n'est pas multiple de 5
# 2142 est divible par 7 mais n'est pas multiple de 5
# 2149 est divible par 7 mais n'est pas multiple de 5
# ...
